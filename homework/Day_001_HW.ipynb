# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %% [markdown]
# # [作業目標]
# - 仿造範例的MAE函數, 自己寫一個MSE函數(參考上面公式)

# %% [markdown]
# # [作業重點]
# - 注意程式的縮排
# - 是否能將數學公式, 轉換為 Python 的函式組合? (In[2], Out[2])

# %%
# 載入基礎套件與代稱
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_absolute_error(y, yp):
    """
    計算 MAE
    Args:
        - y: 實際值
        - yp: 預測值
    Return:
        - mae: MAE
    """
    mae = MAE = sum(abs(y - yp)) / len(y)
    return mae

# 定義 mean_squared_error 這個函數, 計算並傳回 MSE
def mean_squared_error(y, yp):
    mse = MSE = sum((y - yp)**2) / len(y)
    return mse

# %%
# 與範例相同, 不另外解說
w = 3
b = 0.5
x_lin = np.linspace(0, 100, 101)
y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
# 與範例相同, 不另外解說
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 180.474
# The Mean absolute error is 10.671

# %% [markdown]
# # [作業2]
#
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
#
# 資料：Shared Cars Locations
#
# 簡介：
#
#     為了減少擁有的汽車數量，特拉維夫市啟動了一個名為AutoTel的共享汽車項目。該服務的用戶可以使用移動應用程序預訂汽車，並按分鐘付費。該項目於2017年10月推出，吸引了超過7500名用戶，其中超過50％的用戶每周至少使用一次該服務。
#
#     為了使服務可靠，AutoTel必須確保供需在地理空間上保持平衡，這意味著汽車可以在需要的地方和時間使用。這項任務非常困難，因為使用者並不會遵循這個優化規則駕駛及停放車輛。在大多數情況下，汽車的分佈與需求無關：一個原因是，如果汽車停放在郊區，可能需要很長時間才能將另一個用戶帶到需求量很大的市中心;因此，未使用的汽車群經常出現在城市的郊區。
#
# 1. 你選的這組資料為何重要
#
#    現今社會中，共享經濟正在崛起，而如何提升共享經濟的效能，也成為最此產業最重要的問題，這組資料即是利用共享汽車的資料，希望能提升汽車的地理空間可用價值，以增加共享經濟的效能。
#
#
# 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
#
#    AutoTel網站上，每隔兩分鐘抽取停放車輛的位置，持續記錄數個月。
#
#
# 3. 蒐集而來的資料型態為何
#
#    原始數據以CSV格式保存到Google Storage，稍後加載到BigQuery Table。
#
#
# 4. 這組資料想解決的問題如何評估
#
#    使用機器學習，AutoTel可以在給定時間預測汽車的地理空間可用性，並使用預測來修改其業務模型。例如，他們可以修改價格，以便在高需求區域停放汽車更便宜，或計劃維護計劃，以便從高供應低需求區域收集汽車並返回高需求區域。
#
#
#
# # [作業3]
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
#
#    哪種族群會比較頻繁使用自由載客車隊服務？這些客人在哪裡出現比較多？
#
#
# 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
#
#    將過往載客下客的時間地點以及客人的特徵記錄起來。
#
#
# 3. 蒐集而來的資料型態為何
#
#    變數為時間、地點(GPS座標、城市、行政區)、客人資訊(性別、職業)，樣本為各個客人的dataframe資料。
#
#
# 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
#
#    嘗試在該族群出沒的時段地段增派車輛，驗證其消費力較高，使車隊效益增加。
